# %% [markdown]
# Rami, Nicola Srour (2025)
#
# Title: Amazon Sale report dataset, decision tree classifier

# %%
# import needed libraries
import pandas as pd
import sklearn.model_selection
import sklearn.tree
import sklearn.metrics

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# upload dataset and show all columns
df = pd.read_excel("Amazon Sale Report.xlsx")
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#               Order ID       Date                        Status Fulfilment  \
# 0  405-8078784-5731545 2022-04-30                     Cancelled   Merchant
# 1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146 2022-04-30                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU Category Size  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S      Set    S
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL    kurta  3XL
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL    kurta   XL
#
#          ASIN Courier Status  Qty currency  Amount    ship-city   ship-state  \
# 0  B09KXVBD7Z            NaN    0      INR  647.62       MUMBAI  MAHARASHTRA
# 1  B09K3WFS32        Shipped    1      INR  406.00    BENGALURU    KARNATAKA
# 2  B07WV4JV4D        Shipped    1      INR  329.00  NAVI MUMBAI  MAHARASHTRA
#
#    ship-postal-code ship-country  \
# 0          400081.0           IN
# 1          560085.0           IN
# 2          410210.0           IN
#
#                                        promotion-ids    B2B fulfilled-by  \
# 0                                                NaN  False    Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False    Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True          NaN
#
#    Unnamed: 22
# 0          NaN
# 1          NaN
# 2          NaN

# %%
df.shape
# Out:
# (128975, 23)

# %%
# remove columns that are not needed
df = df.drop(['Unnamed: 22' , 'ASIN', 'ship-postal-code', 'Order ID', 'SKU', 'promotion-ids'], axis=1)
# duplicates
df = df.drop_duplicates()
# null
df = df.dropna()
df.head(5)
# Out:
#          Date                        Status Fulfilment Sales Channel   \
# 1  2022-04-30  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 7  2022-04-30  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 12 2022-04-30  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 14 2022-04-30  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 15 2022-04-30  Shipped - Delivered to Buyer   Merchant      Amazon.in
#
#    ship-service-level     Style Category Size Courier Status  Qty currency  \
# 1            Standard   JNE3781    kurta  3XL        Shipped    1      INR
# 7            Standard   JNE3405    kurta    S        Shipped    1      INR
# 12           Standard   JNE3405    kurta   XS        Shipped    1      INR
# 14           Standard     J0351      Set    L        Shipped    1      INR
# 15           Standard  PJNE3368    kurta  6XL        Shipped    1      INR
#
#     Amount  ship-city      ship-state ship-country    B2B fulfilled-by
# 1    406.0  BENGALURU       KARNATAKA           IN  False    Easy Ship
# 7    399.0  HYDERABAD       TELANGANA           IN  False    Easy Ship
# 12   399.0  Amravati.     MAHARASHTRA           IN  False    Easy Ship
# 14   771.0     MUMBAI     MAHARASHTRA           IN  False    Easy Ship
# 15   544.0   GUNTAKAL  ANDHRA PRADESH           IN  False    Easy Ship

# %%
# make sure no null values exist
import missingno as msno
msno.matrix(df, figsize=(10, 10))
plt.show()

# %%
# changed date column values to date data
df['Date'] = pd.to_datetime(df['Date'])

# %%
# use scatter plot to remove outliers

plt.scatter(df.index, df['Amount'])
plt.show()

# %%
df = df[df['Amount'] < 2000]
plt.scatter(df.index, df['Amount'])
plt.show()

# %%
#  counting finding unique values in each column with cateogrical values to know which encoding method to use
uniquestatus = df['Status'].nunique()
uniqueFulfilment = df['Fulfilment'].nunique()
uniqueSalesChannel = df.iloc[:,4].nunique()
uniqueshipservicelevel = df['ship-service-level'].nunique()
uniqueStyle = df['Style'].nunique()
uniquecategory = df['Category'].nunique()
uniqueSize = df['Size'].nunique()
uniqueCourierStatus = df['Courier Status'].nunique()
uniquecurrency = df['currency'].nunique()
uniqueshipcity = df['ship-city'].nunique()
uniqueshipstate = df['ship-state'].nunique()
uniquehipcountry= df['ship-country'].nunique()
uniqueb2b = df['B2B'].nunique()
uniquefulfilledby = df['fulfilled-by'].nunique()
print(uniquestatus, uniqueFulfilment, uniqueSalesChannel, uniqueshipservicelevel, uniqueStyle, uniquecategory, uniqueSize, uniqueCourierStatus , uniquecurrency, uniqueshipcity, uniqueshipstate, uniquehipcountry, uniqueb2b, uniquefulfilledby)
# Out:
# 10 1 1 1 1080 8 11 2 1 4321 57 1 2 1

# %%
# use label encoder on the features columns
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Status'] = encoder.fit_transform(df['Status'])
df['Fulfilment'] = encoder.fit_transform(df['Fulfilment'])
df['Sales Channel'] = encoder.fit_transform(df.iloc[:,4])
df['ship-service-level'] = encoder.fit_transform(df['ship-service-level'])
df['Style'] = encoder.fit_transform(df['Style'])
df['Category'] = encoder.fit_transform(df['Category'])
df['Size'] = encoder.fit_transform(df['Size'])
df['Courier Status'] = encoder.fit_transform(df['Courier Status'])
df['currency'] = encoder.fit_transform(df['currency'])
df['ship-city'] = encoder.fit_transform(df['ship-city'])
df['ship-state'] = encoder.fit_transform(df['ship-state'])
df['ship-country'] = encoder.fit_transform(df['ship-country'])
df['B2B'] = encoder.fit_transform(df['B2B'])
df['fulfilled-by'] = encoder.fit_transform(df['fulfilled-by'])
df['Date'] = encoder.fit_transform(df['Date'])
df = df.drop(df.columns[3], axis=1)
df.head(3)
# Out:
#     Date  Status  Fulfilment  ship-service-level  Style  Category  Size  \
# 1     30       3           0                   0    676         7     0
# 7     30       3           0                   0    412         7     7
# 12    30       3           0                   0    412         7     9
#
#     Courier Status  Qty  currency  Amount  ship-city  ship-state  \
# 1                0    1         0   406.0        387          21
# 7                0    1         0   399.0       1392          47
# 12               0    1         0   399.0        197          26
#
#     ship-country  B2B  fulfilled-by  Sales Channel
# 1              0    0             0              0
# 7              0    0             0              0
# 12             0    0             0              0

# %%
# see types of columns
df.dtypes
# Out:
# Date                    int64
# Status                  int64
# Fulfilment              int64
# ship-service-level      int64
# Style                   int64
# Category                int64
# Size                    int64
# Courier Status          int64
# Qty                     int64
# currency                int64
# Amount                float64
# ship-city               int64
# ship-state              int64
# ship-country            int64
# B2B                     int64
# fulfilled-by            int64
# Sales Channel           int64
# dtype: object

# %%
# show statistics of the dataset
df.describe()
# Out:
#                Date        Status  Fulfilment  ship-service-level  \
# count  32111.000000  32111.000000     32111.0             32111.0
# mean      41.436517      3.384884         0.0                 0.0
# std       24.817671      1.382434         0.0                 0.0
# min        0.000000      0.000000         0.0                 0.0
# 25%       20.000000      3.000000         0.0                 0.0
# 50%       39.000000      3.000000         0.0                 0.0
# 75%       62.000000      3.000000         0.0                 0.0
# max       90.000000      9.000000         0.0                 0.0
#
#               Style      Category          Size  Courier Status           Qty  \
# count  32111.000000  32111.000000  32111.000000    32111.000000  32111.000000
# mean     605.368316      5.452742      6.257513        0.015976      1.003986
# std      302.135764      1.445103      2.896113        0.125384      0.070917
# min        0.000000      0.000000      0.000000        0.000000      1.000000
# 25%      348.000000      4.000000      5.000000        0.000000      1.000000
# 50%      682.000000      6.000000      7.000000        0.000000      1.000000
# 75%      877.000000      7.000000      8.000000        0.000000      1.000000
# max     1079.000000      7.000000     10.000000        1.000000      4.000000
#
#        currency        Amount     ship-city    ship-state  ship-country  \
# count   32111.0  32111.000000  32111.000000  32111.000000       32111.0
# mean        0.0    648.841954   1911.559403     29.003239           0.0
# std         0.0    280.790239   1167.829202     14.947348           0.0
# min         0.0      0.000000      0.000000      0.000000           0.0
# 25%         0.0    458.000000    878.000000     21.000000           0.0
# 50%         0.0    631.000000   1820.000000     26.000000           0.0
# 75%         0.0    771.000000   2767.000000     46.000000           0.0
# max         0.0   1999.000000   4320.000000     56.000000           0.0
#
#                 B2B  fulfilled-by  Sales Channel
# count  32111.000000       32111.0        32111.0
# mean       0.008253           0.0            0.0
# std        0.090470           0.0            0.0
# min        0.000000           0.0            0.0
# 25%        0.000000           0.0            0.0
# 50%        0.000000           0.0            0.0
# 75%        0.000000           0.0            0.0
# max        1.000000           0.0            0.0

# %%
# make sure again no null values exist
import missingno as msno
msno.matrix(df, figsize=(10, 10))
plt.show()

# %%
# find correlation matrix
plt.figure(figsize=(20,10))
corrmatrix =  df.select_dtypes(include=['number']).corr()
sns.heatmap(corrmatrix, annot=True)
plt.show()

# %%
# split the dataset, build, train and test the machine learning models
x = df.drop(['Category'], axis=1)
y = df['Category']
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y)
print("df:", df.shape)
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# df: (32111, 17)
# x_train: (24083, 16)
# y_train: (24083,)
# x_test: (8028, 16)
# y_test: (8028,)

# %%
tree = sklearn.tree.DecisionTreeClassifier()
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = tree.predict(x_test)
acc = sklearn.metrics.accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.9945191828599901

# %%
ypredprob = tree.predict_proba(x_test)
roc = sklearn.metrics.roc_auc_score(y_test,ypredprob, multi_class='ovo')
roc2 = sklearn.metrics.roc_auc_score(y_test,ypredprob, multi_class='ovr')
print(roc, roc2)
# Out:
# 0.9903765585074965 0.9911312661104391

# %% [markdown]
# Dataset Reference:
# ANil, (2022), Summary, Data.world, Available at: https://data.world/anilsharma87/sales, (Accessed : 04/04/2025)
